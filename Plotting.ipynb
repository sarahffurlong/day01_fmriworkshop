# %%
from nilearn.plotting import plot_roi, plot_stat_map, plot_glass_brain
from glob import glob
# %matplotlib inline

# %% [markdown]
# ## Exercise
# Adjust your for loop to plot the same cut coordinates for all maps

# %%
plot_roi("/Users/Sarah/Desktop/data/subs/sub-10159/anat/sub-10159_T1w_brain_mask.nii.gz", 
         "/Users/Sarah/Desktop/data/subs/sub-10159/anat/sub-10159_T1w.nii.gz", display_mode='y')

# %%
for map_file in glob("/Users/Sarah/Desktop/data/subdervs/derivatives/task/Group/subgroup_analysis.gfeat/cope1.feat/thresh_zstat*.nii.gz"):
    plot_stat_map(map_file, threshold=3.1, cut_coords=(32,-57,-28))

# %%
plot_stat_map?

# %%
for map_file in glob("/Users/Sarah/Desktop/data/subdervs/derivatives/task/Group/subgroup_analysis.gfeat/cope1.feat/thresh_zstat*.nii.gz"):
    plot_glass_brain(map_file, threshold=3.1)
